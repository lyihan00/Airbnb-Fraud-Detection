# %% [markdown]
# # Import Libraries and Dataset

# %%
# !pip install sklearn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score
from sklearn.metrics import roc_curve, precision_recall_curve, roc_auc_score
import warnings
import os

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/BT4012 Project')
os.chdir('Datasets/')
# Out:
# Mounted at /content/drive

# %%
# Import Datasets for Train and Test
train_vanilla = pd.read_csv('train_vanilla.csv')
train_undersampled = pd.read_csv('train_undersampled.csv')
train_synthetic = pd.read_csv('train_synthetic.csv')

test_df = pd.read_csv('test_data.csv')

# %% [markdown]
# # Split Datasets into features and target
# Target column: `fraud`

# %% [markdown]
# ## Split Vanilla Train Dataset

# %%
train_vanilla.head()
# Out:
#    price_per_occupant  reviews_per_month  review_scores_rating  \
# 0           -0.606310           0.295724              0.681369
# 1            0.001632           0.873947              0.354150
# 2           -0.623680           0.904650              0.572296
# 3            1.130667          -0.599755              0.463223
# 4            0.081533          -0.737915             -0.300289
#
#    number_of_reviews  amenities     price  host_total_listings_count  \
# 0          -0.391250   0.470134  0.182401                  -0.147658
# 1           1.108677   0.071405 -0.362402                  -0.327982
# 2          -0.057933   1.611167  1.090404                  -0.290673
# 3          -0.002380  -0.530711  1.272005                  -0.327982
# 4          -0.280144  -0.433040  0.175137                  -0.265801
#
#    minimum_nights  cancellation_policy  host_response_rate  accommodates  \
# 0       -0.222934                    2            0.282403      1.632424
# 1       -0.122216                    1            0.369319     -0.597208
# 2       -0.222934                    2            0.369319      3.862055
# 3       -0.222934                    1            0.369319     -0.039800
# 4       -0.021499                    2            0.108571     -0.039800
#
#    host_total_listings_count_group      beds  bathrooms  property_type  \
# 0                                3  1.368227  -0.449455              0
# 1                                1 -0.619138  -0.449455              0
# 2                                3  5.342957   1.498427              0
# 3                                1 -0.619138  -0.449455              0
# 4                                3 -0.619138  -0.449455              0
#
#    bedrooms  host_identity_verified  fraud
# 0 -0.343801                       1      0
# 1 -0.343801                       1      0
# 2  2.262622                       1      0
# 3 -0.343801                       1      0
# 4 -0.343801                       1      1

# %%
X_train_vanilla = train_vanilla.copy().drop(columns='fraud')
Y_train_vanilla = train_vanilla['fraud']

# %% [markdown]
# ## Split Undersampled Train Dataset

# %%
train_undersampled.head()
# Out:
#    price_per_occupant  reviews_per_month  review_scores_rating  \
# 0            0.081533           1.641501              0.463223
# 1            0.157960          -0.410425              0.681369
# 2            0.856224          -0.563936              0.136003
# 3            0.335131          -0.840255             -1.500094
# 4           -0.805020          -0.410425              0.681369
#
#    number_of_reviews  amenities     price  host_total_listings_count  \
# 0           2.830816  -0.433040  0.175137                  -0.240929
# 1          -0.530132  -0.318132  1.272005                   1.612050
# 2          -0.419026   0.336841  0.233249                  -0.203621
# 3          -0.474579  -0.634128 -0.129953                  -0.010861
# 4          -0.530132   1.633000 -0.405986                   1.574742
#
#    minimum_nights  cancellation_policy  host_response_rate  accommodates  \
# 0       -0.021499                    2            0.369319     -0.039800
# 1        1.690704                    1            0.021655      1.075016
# 2       -0.122216                    1            0.108571     -0.597208
# 3        0.381373                    2            0.369319     -0.597208
# 4       -0.122216                    2            0.369319      1.075016
#
#    host_total_listings_count_group      beds  bathrooms  property_type  \
# 0                                3 -0.619138  -0.449455              0
# 1                                3  0.374545   1.498427              0
# 2                                3 -0.619138  -0.449455              0
# 3                                3 -0.619138  -0.449455              0
# 4                                3  0.374545   1.498427              0
#
#    bedrooms  host_identity_verified  fraud
# 0 -0.343801                       1      0
# 1  0.959411                       1      0
# 2 -1.647013                       1      0
# 3 -1.647013                       1      0
# 4  0.959411                       1      0

# %%
X_train_undersampled = train_undersampled.copy().drop(columns='fraud')
Y_train_undersampled = train_undersampled['fraud']

# %% [markdown]
# ## Split Synthetic Train Dataset

# %%
train_synthetic.head()
# Out:
#    price_per_occupant  reviews_per_month  review_scores_rating  \
# 0           -0.606310           0.295724              0.681369
# 1            0.001632           0.873947              0.354150
# 2           -0.623680           0.904650              0.572296
# 3            1.130667          -0.599755              0.463223
# 4            0.081533          -0.737915             -0.300289
#
#    number_of_reviews  amenities     price  host_total_listings_count  \
# 0          -0.391250   0.470134  0.182401                  -0.147658
# 1           1.108677   0.071405 -0.362402                  -0.327982
# 2          -0.057933   1.611167  1.090404                  -0.290673
# 3          -0.002380  -0.530711  1.272005                  -0.327982
# 4          -0.280144  -0.433040  0.175137                  -0.265801
#
#    minimum_nights  cancellation_policy  host_response_rate  accommodates  \
# 0       -0.222934                    2            0.282403      1.632424
# 1       -0.122216                    1            0.369319     -0.597208
# 2       -0.222934                    2            0.369319      3.862055
# 3       -0.222934                    1            0.369319     -0.039800
# 4       -0.021499                    2            0.108571     -0.039800
#
#    host_total_listings_count_group      beds  bathrooms  property_type  \
# 0                                3  1.368227  -0.449455              0
# 1                                1 -0.619138  -0.449455              0
# 2                                3  5.342957   1.498427              0
# 3                                1 -0.619138  -0.449455              0
# 4                                3 -0.619138  -0.449455              0
#
#    bedrooms  host_identity_verified  fraud
# 0 -0.343801                       1      0
# 1 -0.343801                       1      0
# 2  2.262622                       1      0
# 3 -0.343801                       1      0
# 4 -0.343801                       1      1

# %%
X_train_synthetic = train_synthetic.copy().drop(columns='fraud')
Y_train_synthetic = train_synthetic['fraud']

# %% [markdown]
# ## Splitting Test Set

# %%
test_df.head()
# Out:
#    price_per_occupant  reviews_per_month  review_scores_rating  \
# 0           -0.581992          -0.323436              0.681369
# 1           -0.258915          -0.062468              0.354150
# 2            0.783271          -0.410425              0.681369
# 3           -0.571571           0.244554              0.136003
# 4           -0.910281          -0.113638             -0.627509
#
#    number_of_reviews  amenities     price  host_total_listings_count  \
# 0          -0.169039  -0.120491 -0.769187                  -0.327982
# 1          -0.307921  -1.119039 -0.544002                  -0.327982
# 2          -0.530132   1.237717  1.635207                  -0.147658
# 3          -0.196815   1.715733 -0.761923                  -0.321764
# 4           0.053173   1.660577 -0.180801                  -0.327982
#
#    minimum_nights  cancellation_policy  host_response_rate  accommodates  \
# 0       -0.021499                    2            0.369319     -0.597208
# 1       -0.122216                    1            0.369319     -0.597208
# 2       -0.222934                    2            0.282403      0.517608
# 3       -0.222934                    1           -0.934420     -0.597208
# 4       -0.021499                    0            0.369319      2.747240
#
#    host_total_listings_count_group      beds  bathrooms  property_type  \
# 0                                1 -0.619138  -0.449455              0
# 1                                1 -0.619138  -0.449455              4
# 2                                3  0.374545  -0.449455              0
# 3                                2 -0.619138  -0.449455              0
# 4                                1  3.355592  -0.449455              8
#
#    bedrooms  host_identity_verified  fraud
# 0 -0.343801                       1      0
# 1 -0.343801                       0      0
# 2 -0.343801                       1      0
# 3 -0.343801                       0      0
# 4  2.262622                       1      1

# %%
X_test = test_df.copy().drop(columns='fraud')
Y_test = test_df['fraud']

# %% [markdown]
# # Logistic Regression Classifer
# Logistic regression is a classification algorithm that uses supervised learning to predict the likelihood of a target variable.

# %% [markdown]
# ## Fitting Logistic Regression Classifer on Train Sets
# ### Train Sets: Vanilla, Undersampled, Synthetic

# %%
# Fit Logistic Regression on Vanilla
lr_vanilla = LogisticRegression(random_state=42)
lr_vanilla.fit(X_train_vanilla.values, Y_train_vanilla)
# Out:
# LogisticRegression(random_state=42)

# %%
# Fit Logistic Regression on Undersampled
lr_undersampled = LogisticRegression(random_state=42)
lr_undersampled.fit(X_train_undersampled.values, Y_train_undersampled)
# Out:
# LogisticRegression(random_state=42)

# %%
# Fit Logistic Regression on Synthetic
lr_synthetic = LogisticRegression(random_state=42)
lr_synthetic.fit(X_train_synthetic.values, Y_train_synthetic)
# Out:
# LogisticRegression(random_state=42)

# %% [markdown]
# ## Cross-Validate using GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'penalty': ['l1', 'l2'],  # regularization penalty
    'C': np.logspace(-10, 5, 10),  # regularization strength
    'solver': ['liblinear']  # solver for optimization problem
}

# %% [markdown]
# ### Vanilla Train Set Logistic Regression

# %%
vanilla_grid_search = GridSearchCV(lr_vanilla, param_grid, cv=5, scoring='accuracy', verbose=1)

vanilla_grid_search.fit(X_train_vanilla, Y_train_vanilla)

vanilla_best_params = vanilla_grid_search.best_params_
print(f"Best Hyperparameters: {vanilla_best_params}")

vanilla_best_score = vanilla_grid_search.best_score_
print(f"Best Accuracy Score: {vanilla_best_score}")

lr_tuned_vanilla = vanilla_grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Hyperparameters: {'C': 1.0, 'penalty': 'l2', 'solver': 'liblinear'}
# Best Accuracy Score: 0.8455479693605497

# %% [markdown]
# ### Undersampled Train Set Logistic Regression

# %%
undersampled_grid_search = GridSearchCV(lr_undersampled, param_grid, cv=5, scoring='accuracy', verbose=1)

undersampled_grid_search.fit(X_train_undersampled, Y_train_undersampled)

undersampled_best_params = undersampled_grid_search.best_params_
print(f"Best Hyperparameters: {undersampled_best_params}")

undersampled_best_score = undersampled_grid_search.best_score_
print(f"Best Accuracy Score: {undersampled_best_score}")

lr_tuned_undersampled = undersampled_grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Hyperparameters: {'C': 0.021544346900318867, 'penalty': 'l1', 'solver': 'liblinear'}
# Best Accuracy Score: 0.7992906934083404

# %% [markdown]
# ### Synthetic Train Set Logistic Regression

# %%
synthetic_grid_search = GridSearchCV(lr_synthetic, param_grid, cv=5, scoring='accuracy', verbose=1)

synthetic_grid_search.fit(X_train_synthetic, Y_train_synthetic)

synthetic_best_params = synthetic_grid_search.best_params_
print(f"Best Hyperparameters: {synthetic_best_params}")

synthetic_best_score = synthetic_grid_search.best_score_
print(f"Best Accuracy Score: {synthetic_best_score}")

lr_tuned_synthetic = synthetic_grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Hyperparameters: {'C': 1.0, 'penalty': 'l1', 'solver': 'liblinear'}
# Best Accuracy Score: 0.8161817701393691

# %% [markdown]
# ## Predict on Test set
# Predict on test set based on Logistic Regression classifier with tuned hyperparameters determined by GridSearchCV.

# %% [markdown]
# ### Vanilla Trained

# %%
pred_vanilla = lr_tuned_vanilla.predict(X_test)

vanilla_cf = confusion_matrix(Y_test, pred_vanilla)
print(f"Confusion Matrix for Logistic Regression trained on Vanilla: \n{vanilla_cf}")

vanilla_acc = accuracy_score(Y_test, pred_vanilla)
print(f"Accuracy Score for Logistic Regression trained on Vanilla = {vanilla_acc*100:.2f}%")

vanilla_pre = precision_score(Y_test, pred_vanilla)
print(f"Precision Score for Logistic Regression trained on Vanilla = {vanilla_pre*100:.2f}%")

vanilla_rec = recall_score(Y_test, pred_vanilla)
print(f"Recall Score for Logistic Regression trained on Vanilla = {vanilla_rec*100:.2f}%")

vanilla_f1 = f1_score(Y_test, pred_vanilla)
print(f"F1 Score for Logistic Regression trained on Vanilla = {vanilla_f1*100:.2f}%")

vanilla_roc_auc = roc_auc_score(Y_test, pred_vanilla)
print(f"ROC AUC Score for Logistic Regression trained on Vanilla = {vanilla_roc_auc*100:.2f}%")
# Out:
# Confusion Matrix for Logistic Regression trained on Vanilla:
# [[658  16]
#  [118  96]]
# Accuracy Score for Logistic Regression trained on Vanilla = 84.91%
# Precision Score for Logistic Regression trained on Vanilla = 85.71%
# Recall Score for Logistic Regression trained on Vanilla = 44.86%
# F1 Score for Logistic Regression trained on Vanilla = 58.90%
# ROC AUC Score for Logistic Regression trained on Vanilla = 71.24%

# %% [markdown]
# ### Undersampled Trained

# %%
pred_undersampled = lr_tuned_undersampled.predict(X_test)

undersampled_cf = confusion_matrix(Y_test, pred_undersampled)
print(f"Confusion Matrix for Logistic Regression trained on Undersampled: \n{undersampled_cf}")

undersampled_acc = accuracy_score(Y_test, pred_undersampled)
print(f"Accuracy Score for Logistic Regression trained on Undersampled = {undersampled_acc*100:.2f}%")

undersampled_pre = precision_score(Y_test, pred_undersampled)
print(f"Precision Score for Logistic Regression trained on Undersampled = {undersampled_pre*100:.2f}%")

undersampled_rec = recall_score(Y_test, pred_undersampled)
print(f"Recall Score for Logistic Regression trained on Undersampled = {undersampled_rec*100:.2f}%")

undersampled_f1 = f1_score(Y_test, pred_undersampled)
print(f"F1 Score for Logistic Regression trained on Undersampled = {undersampled_f1*100:.2f}%")

undersampled_roc_auc = roc_auc_score(Y_test, pred_undersampled)
print(f"ROC AUC Score for Logistic Regression trained on Undersampled = {undersampled_roc_auc*100:.2f}%")
# Out:
# Confusion Matrix for Logistic Regression trained on Undersampled:
# [[570 104]
#  [ 39 175]]
# Accuracy Score for Logistic Regression trained on Undersampled = 83.90%
# Precision Score for Logistic Regression trained on Undersampled = 62.72%
# Recall Score for Logistic Regression trained on Undersampled = 81.78%
# F1 Score for Logistic Regression trained on Undersampled = 70.99%
# ROC AUC Score for Logistic Regression trained on Undersampled = 83.17%

# %% [markdown]
# ### Synthetic Trained

# %%
pred_synthetic = lr_tuned_synthetic.predict(X_test)

synthetic_cf = confusion_matrix(Y_test, pred_synthetic)
print(f"Confusion Matrix for Logistic Regression trained on Synthetic: \n{synthetic_cf}")

synthetic_acc = accuracy_score(Y_test, pred_synthetic)
print(f"Accuracy Score for Logistic Regression trained on Synthetic = {synthetic_acc*100:.2f}%")

synthetic_pre = precision_score(Y_test, pred_synthetic)
print(f"Precision Score for Logistic Regression trained on Synthetic = {synthetic_pre*100:.2f}%")

synthetic_rec = recall_score(Y_test, pred_synthetic)
print(f"Recall Score for Logistic Regression trained on Synthetic = {synthetic_rec*100:.2f}%")

synthetic_f1 = f1_score(Y_test, pred_synthetic)
print(f"F1 Score for Logistic Regression trained on Synthetic = {synthetic_f1*100:.2f}%")

synthetic_roc_auc = roc_auc_score(Y_test, pred_synthetic)
print(f"ROC AUC Score for Logistic Regression trained on Synthetic = {synthetic_roc_auc*100:.2f}%")
# Out:
# Confusion Matrix for Logistic Regression trained on Synthetic:
# [[577  97]
#  [ 55 159]]
# Accuracy Score for Logistic Regression trained on Synthetic = 82.88%
# Precision Score for Logistic Regression trained on Synthetic = 62.11%
# Recall Score for Logistic Regression trained on Synthetic = 74.30%
# F1 Score for Logistic Regression trained on Synthetic = 67.66%
# ROC AUC Score for Logistic Regression trained on Synthetic = 79.95%

# %% [markdown]
# ## Plots to show Performance

# %% [markdown]
# ### Precision-Recall Curve

# %%
vanilla_prerec_curve = precision_recall_curve(Y_test, pred_vanilla)
undersampled_prerec_curve = precision_recall_curve(Y_test, pred_undersampled)
synthetic_prerec_curve = precision_recall_curve(Y_test, pred_synthetic)

plt.figure(figsize=(7,4))
plt.plot(vanilla_prerec_curve[0], vanilla_prerec_curve[1], label='Vanilla Trained')
plt.plot(undersampled_prerec_curve[0], undersampled_prerec_curve[1], label='Undersampled Trained')
plt.plot(synthetic_prerec_curve[0], synthetic_prerec_curve[1], label='Synthetic Trained')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### ROC AUC

# %%
vanilla_roc_curve = roc_curve(Y_test, pred_vanilla)
undersampled_roc_curve = roc_curve(Y_test, pred_undersampled)
synthetic_roc_curve = roc_curve(Y_test, pred_synthetic)

plt.figure(figsize=(7,4))
plt.plot(vanilla_roc_curve[0], vanilla_roc_curve[1], label='Vanilla Trained')
plt.plot(undersampled_roc_curve[0], undersampled_roc_curve[1], label='Undersampled Trained')
plt.plot(synthetic_roc_curve[0], synthetic_roc_curve[1], label='Synthetic Trained')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.grid()
plt.show()
